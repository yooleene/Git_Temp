# %%
설치시 ssl 오류 해결 : win command에서 ssl 오류시는 마지막 분장에 한깐 띄우고 아래문장 붙임
--trusted-host pypi.org --trusted-host files.pythonhosted.org

# %%
pip list로 확인시 오류 발생
1.pip 업그레이드 실시 : python -m pip install --upgrade pip
2.아무 라이브러리(pyautogui ot pandas 등) 설치후 pip list로 확인

# %%
selenium 특정 버전 설치 or 업/다운그레이드 설치
pip install selenium==3.141.0
pip install --upgrade selenium==3.141.0

# %%
Ie WebDriver 버전별 다운
http://selenium-release.storage.googleapis.com/index.html

PyAutoGUI 공식홈
https://pyautogui.readthedocs.io/en/latest/index.html

selenium 공식홈
https://www.selenium.dev/ko/documentation/getting_started/
