# %% [markdown]
# # 웹드라이버/라이브러리 불러오기

# %%
from selenium import webdriver

# %% [markdown]
# # 웹사이트 접속

# %%
driver = webdriver.Ie('IEDriverServer')
#웹드라이버 파일이 특정 위치에 있을때는 상대 경로나 절대 경로로 직접 기록하면 된다.

driver.get('http://naver.com')

driver.maximize_window() #로드된 드라이버의 윈도우 창을 최대화 한다.
